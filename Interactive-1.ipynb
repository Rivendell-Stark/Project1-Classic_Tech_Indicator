# %% [markdown]
# Connected to quant (Python 3.13.9)

# %% [markdown]
# Connected to quant (Python 3.13.9)

# %%
import numpy as np
import pandas as pd
import psycopg2 as pg

# %%
kc1 = pd.read_excel("D:/Projects/Quant/CSMAR-Data/科创16-20.xlsx", header=0, skiprows=[1,2])
# Out:
# C:\Users\a1226\AppData\Roaming\Python\Python313\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
kc1.head(5)
# Out:
#     Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0  688001  2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1  688001  2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2  688001  2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3  688001  2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4  688001  2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
#
#       Dsmvosd     Dsmvtll  ...  Markettype    Capchgdt  Trdsta  Ahshrtrd_D  \
# 0  2011851.69  22255500.0  ...          32  2019-07-22       1       16200
# 1  1766442.03  19540730.0  ...          32  2019-07-22       1       24475
# 2  1867578.36  20659520.0  ...          32  2019-07-22       1       20648
# 3  1983214.52  21938710.0  ...          32  2019-07-22       1       19808
# 4  1836403.72  20314660.0  ...          32  2019-07-22       1       12490
#
# ...

# %%
kc1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29453 entries, 0 to 29452
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stkcd          29453 non-null  int64
#  1   Trddt          29453 non-null  object
#  2   Opnprc         29453 non-null  float64
#  3   Hiprc          29453 non-null  float64
#  4   Loprc          29453 non-null  float64
#  5   Clsprc         29453 non-null  float64
#  6   Dnshrtrd       29453 non-null  int64
#  7   Dnvaltrd       29453 non-null  int64
#  8   Dsmvosd        29453 non-null  float64
#  9   Dsmvtll        29453 non-null  float64
#  10  Dretwd         29453 non-null  float64
#  11  Dretnd         29453 non-null  float64
#  12  Adjprcwd       29453 non-null  float64
#  13  Adjprcnd       29453 non-null  float64
#  14  Markettype     29453 non-null  int64
#  15  Capchgdt       29453 non-null  object
#  16  Trdsta         29453 non-null  int64
# ...

# %%
kc2 = pd.read_excel("D:/Projects/Quant/CSMAR-Data/科创20-25.xlsx", header=0, skiprows=[1,2])
# Out:
# C:\Users\a1226\AppData\Roaming\Python\Python313\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
kc = pd.concat([kc1,kc2], axis=1,ignore_index=True)

# %%
kc.info
# Out:
# <bound method DataFrame.info of               0           1      2      3      4      5           6   \
# 0       688001.0  2019-07-22  55.40  72.02  39.59  55.50  29010754.0
# 1       688001.0  2019-07-23  46.92  52.65  45.01  48.73  10060618.0
# 2       688001.0  2019-07-24  48.90  52.18  48.90  51.52   9698629.0
# 3       688001.0  2019-07-25  52.78  57.42  52.70  54.71  13056123.0
# 4       688001.0  2019-07-26  54.00  54.00  50.01  50.66   8174241.0
# ...          ...         ...    ...    ...    ...    ...         ...
# 574660       NaN         NaN    NaN    NaN    NaN    NaN         NaN
# 574661       NaN         NaN    NaN    NaN    NaN    NaN         NaN
# 574662       NaN         NaN    NaN    NaN    NaN    NaN         NaN
# 574663       NaN         NaN    NaN    NaN    NaN    NaN         NaN
# 574664       NaN         NaN    NaN    NaN    NaN    NaN         NaN
#
#                   7           8           9   ...  38          39  40    41  \
# ...

# %%
kc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574665 entries, 0 to 574664
# Data columns (total 48 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       29453 non-null   float64
#  1   1       29453 non-null   object
#  2   2       29453 non-null   float64
#  3   3       29453 non-null   float64
#  4   4       29453 non-null   float64
#  5   5       29453 non-null   float64
#  6   6       29453 non-null   float64
#  7   7       29453 non-null   float64
#  8   8       29453 non-null   float64
#  9   9       29453 non-null   float64
#  10  10      29453 non-null   float64
#  11  11      29453 non-null   float64
#  12  12      29453 non-null   float64
#  13  13      29453 non-null   float64
#  14  14      29453 non-null   float64
#  15  15      29453 non-null   object
#  16  16      29453 non-null   float64
#  17  17      29453 non-null   float64
#  18  18      29453 non-null   float64
#  19  19      29453 non-null   float64
# ...

# %%
kc = pd.concat([kc1,kc2])

# %%
kc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 604118 entries, 0 to 574664
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Stkcd          604118 non-null  int64
#  1   Trddt          604118 non-null  object
#  2   Opnprc         604118 non-null  float64
#  3   Hiprc          604118 non-null  float64
#  4   Loprc          604118 non-null  float64
#  5   Clsprc         604118 non-null  float64
#  6   Dnshrtrd       604118 non-null  int64
#  7   Dnvaltrd       604118 non-null  int64
#  8   Dsmvosd        604118 non-null  float64
#  9   Dsmvtll        604118 non-null  float64
#  10  Dretwd         604118 non-null  float64
#  11  Dretnd         604118 non-null  float64
#  12  Adjprcwd       604118 non-null  float64
#  13  Adjprcnd       604118 non-null  float64
#  14  Markettype     604118 non-null  int64
#  15  Capchgdt       604118 non-null  object
#  16  Trdsta         604118 non-null  int64
# ...

# %%
kc.head(10)
# Out:
#     Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0  688001  2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1  688001  2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2  688001  2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3  688001  2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4  688001  2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# 5  688001  2019-07-29   51.40  55.85  51.40   55.48  10904898   590086172
# 6  688001  2019-07-30   55.40  59.87  53.39   56.79  13962223   794250429
# 7  688001  2019-07-31   57.02  59.69  55.58   58.59  11634422   674971907
# 8  688001  2019-08-01   57.90  70.31  57.00   68.49  19280785  1220204571
# 9  688001  2019-08-02   65.68  78.58  65.27   69.92  20888101  1501009164
#
#       Dsmvosd     Dsmvtll  ...  Markettype    Capchgdt  Trdsta  Ahshrtrd_D  \
# 0  2011851.69  22255500.0  ...          32  2019-07-22       1       16200
# ...

# %%
kc.tail(10)
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 574655  689009  2025-10-27   62.82  63.78  60.80   63.25  33015626
# 574656  689009  2025-10-28   62.70  62.72  61.33   61.34  14984090
# 574657  689009  2025-10-29   61.10  61.73  60.10   61.66  10647548
# 574658  689009  2025-10-30   61.10  61.53  60.00   60.03  11625964
# 574659  689009  2025-10-31   59.61  61.35  59.60   60.70   8704046
# 574660  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 574661  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 574662  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 574663  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 574664  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Markettype    Capchgdt  \
# 574655  2058867954  34962928.30  45367847.42  ...          32  2025-09-30
# 574656   926097745  33907130.78  43997846.01  ...          32  2025-09-30
# ...

# %%
kc_adj = pd.read_excel("D:/Projects/Quant/CSMAR-Data/TRD_AdjustFactor.xlsx", header=0, skiprows=[1,2])
# Out:
# C:\Users\a1226\AppData\Roaming\Python\Python313\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
kc_adj.head(10)
# Out:
#   TradingDate  Symbol  FwardFactor  BwardFactor  CumulateFwardFactor  \
# 0  2020-05-22  688001     0.996895     1.003115             0.969177
# 1  2021-06-08  688001     0.995431     1.004589             0.972196
# 2  2022-08-05  688001     0.993858     1.006180             0.976658
# 3  2023-06-15  688001     0.990037     1.010064             0.982694
# 4  2024-06-20  688001     0.992583     1.007473             0.992583
# 5  2020-06-10  688002     0.998910     1.001091             0.984601
# 6  2021-06-17  688002     0.998421     1.001581             0.985676
# 7  2022-06-16  688002     0.997222     1.002786             0.987235
# 8  2023-06-28  688002     0.997527     1.002479             0.989985
# 9  2024-07-04  688002     0.995534     1.004486             0.992439
#
#    CumulateBwardFactor
# 0             1.003115
# 1             1.007718
# 2             1.013946
# 3             1.024150
# 4             1.031804
# 5             1.001091
# 6             1.002674
# ...

# %%
kc_adj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TradingDate          2087 non-null   object
#  1   Symbol               2087 non-null   int64
#  2   FwardFactor          2087 non-null   float64
#  3   BwardFactor          2087 non-null   float64
#  4   CumulateFwardFactor  2087 non-null   float64
#  5   CumulateBwardFactor  2087 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 98.0+ KB

# %%
kc_merged = pd.merge(left=kc, right=kc_adj,how='left', left_on=["Trddt",'Stkcd'],right_on=["TradingDate","Symbol"])

# %%
kc_merged.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 kc_merged.shape()
#
# TypeError: 'tuple' object is not callable

# %%
kc_merged.shape
# Out:
# (604118, 30)

# %%
kc.shape
# Out:
# (604118, 24)

# %%
kc_merged = kc_merged.drop(columns=["TradingDate","Symbol"])

# %%
kc_merged.shape
# Out:
# (604118, 28)

# %%
kc_merged.head(10)
# Out:
#     Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0  688001  2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1  688001  2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2  688001  2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3  688001  2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4  688001  2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# 5  688001  2019-07-29   51.40  55.85  51.40   55.48  10904898   590086172
# 6  688001  2019-07-30   55.40  59.87  53.39   56.79  13962223   794250429
# 7  688001  2019-07-31   57.02  59.69  55.58   58.59  11634422   674971907
# 8  688001  2019-08-01   57.90  70.31  57.00   68.49  19280785  1220204571
# 9  688001  2019-08-02   65.68  78.58  65.27   69.92  20888101  1501009164
#
#       Dsmvosd     Dsmvtll  ...  Ahvaltrd_D  PreClosePrice  ChangeRatio  \
# 0  2011851.69  22255500.0  ...    899100.0          24.26     1.287716
# ...

# %%
kc_merged[(df_merged['Trddt'] >= '2020-05-01') & 
    (df_merged['Trddt'] <= '2020-05-31') & (kc_merged["Stkcd"==688001)]][["Trddt","BwardFactor","CumulateBwardFactor"]]
# Out:
#   Cell In[23], line 2
#     (df_merged['Trddt'] <= '2020-05-31') & (kc_merged["Stkcd"==688001)]][["Trddt","BwardFactor","CumulateBwardFactor"]]
#                                                                      ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
kc_merged[(df_merged['Trddt'] >= '2020-05-01') & 
    (df_merged['Trddt'] <= '2020-05-31') & (kc_merged["Stkcd"==688001])][["Trddt","BwardFactor","CumulateBwardFactor"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 kc_merged[(df_merged['Trddt'] >= '2020-05-01') &
#       2     (df_merged['Trddt'] <= '2020-05-31') & (kc_merged["Stkcd"==688001])][["Trddt","BwardFactor","CumulateBwardFactor"]]
#
# NameError: name 'df_merged' is not defined

# %%
kc_merged[(kc_merged['Trddt'] >= '2020-05-01') & 
    (kc_merged['Trddt'] <= '2020-05-31') & (kc_merged["Stkcd"==688001)]][["Trddt","BwardFactor","CumulateBwardFactor"]]
# Out:
#   Cell In[25], line 2
#     (kc_merged['Trddt'] <= '2020-05-31') & (kc_merged["Stkcd"==688001)]][["Trddt","BwardFactor","CumulateBwardFactor"]]
#                                                                      ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
kc_merged[(kc_merged['Trddt'] >= '2020-05-01') & 
    (kc_merged['Trddt'] <= '2020-05-31') & (kc_merged["Stkcd"==688001])][["Trddt","BwardFactor","CumulateBwardFactor"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
# ...

# %%
kc_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604118 entries, 0 to 604117
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Stkcd                604118 non-null  int64
#  1   Trddt                604118 non-null  object
#  2   Opnprc               604118 non-null  float64
#  3   Hiprc                604118 non-null  float64
#  4   Loprc                604118 non-null  float64
#  5   Clsprc               604118 non-null  float64
#  6   Dnshrtrd             604118 non-null  int64
#  7   Dnvaltrd             604118 non-null  int64
#  8   Dsmvosd              604118 non-null  float64
#  9   Dsmvtll              604118 non-null  float64
#  10  Dretwd               604118 non-null  float64
#  11  Dretnd               604118 non-null  float64
#  12  Adjprcwd             604118 non-null  float64
#  13  Adjprcnd             604118 non-null  float64
# ...

# %%
type(kc_merged["Trddt",1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Trddt', 1)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ...

# %%
type(kc_merged.loc["Trddt",1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ...

# %%
type(kc_merged.loc[1,"Trddt"])
# Out:
# str

# %%
kc_merged.loc[1,"Trddt"]
# Out:
# '2019-07-23'

# %%
kc_merged["Trddt"] = pd.to_datetime(kc_merged["Trddt"])

# %%
kc_merged.loc[1,"Trddt"]
# Out:
# Timestamp('2019-07-23 00:00:00')

# %%
type(kc_merged.loc[1,"Trddt"])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
t1 = pd.to_datetime('2020-05-01')

# %%
t2 = pd.to_datetime('2020-05-31')

# %%
kc_merged[(kc_merged['Trddt'] >= t1) & 
    (kc_merged['Trddt'] <= t2) & (kc_merged["Stkcd"==688001])][["Trddt","BwardFactor","CumulateBwardFactor"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
# ...

# %%
kc_merged[(kc_merged['Trddt'] >= t1) & (kc_merged['Trddt'] <= t2) & (kc_merged["Stkcd"==688001])][["Trddt","BwardFactor","CumulateBwardFactor"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ...

# %%
kc_merged[(kc_merged['Trddt'] >= t1) & (kc_merged['Trddt'] <= t2) & (kc_merged["Stkcd"]==688001)][["Trddt","BwardFactor","CumulateBwardFactor"]]
# Out:
#          Trddt  BwardFactor  CumulateBwardFactor
# 190 2020-05-06          NaN                  NaN
# 191 2020-05-07          NaN                  NaN
# 192 2020-05-08          NaN                  NaN
# 193 2020-05-11          NaN                  NaN
# 194 2020-05-12          NaN                  NaN
# 195 2020-05-13          NaN                  NaN
# 196 2020-05-14          NaN                  NaN
# 197 2020-05-15          NaN                  NaN
# 198 2020-05-18          NaN                  NaN
# 199 2020-05-19          NaN                  NaN
# 200 2020-05-20          NaN                  NaN
# 201 2020-05-21          NaN                  NaN
# 202 2020-05-22     1.003115             1.003115
# 203 2020-05-25          NaN                  NaN
# 204 2020-05-26          NaN                  NaN
# 205 2020-05-27          NaN                  NaN
# 206 2020-05-28          NaN                  NaN
# 207 2020-05-29          NaN                  NaN

# %%
kc_merged[['FwardFactor', 'CumulateFwardFactor','BwardFactor', 'CumulateBwardFactor']] = kc_merged.groupby('Stkcd')[['FwardFactor', 'CumulateFwardFactor','BwardFactor', 'CumulateBwardFactor']].fillna(method='ffill')
# Out:
# <ipython-input-40-5839228b1d8b>:1: FutureWarning: DataFrameGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use DataFrame.fillna instead
#   kc_merged[['FwardFactor', 'CumulateFwardFactor','BwardFactor', 'CumulateBwardFactor']] = kc_merged.groupby('Stkcd')[['FwardFactor', 'CumulateFwardFactor','BwardFactor', 'CumulateBwardFactor']].fillna(method='ffill')
# <ipython-input-40-5839228b1d8b>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   kc_merged[['FwardFactor', 'CumulateFwardFactor','BwardFactor', 'CumulateBwardFactor']] = kc_merged.groupby('Stkcd')[['FwardFactor', 'CumulateFwardFactor','BwardFactor', 'CumulateBwardFactor']].fillna(method='ffill')

# %%
kc_merged[(kc_merged['Trddt'] >= t1) & (kc_merged['Trddt'] <= t2) & (kc_merged["Stkcd"]==688001)][["Trddt","BwardFactor","CumulateBwardFactor"]]
# Out:
#          Trddt  BwardFactor  CumulateBwardFactor
# 190 2020-05-06          NaN                  NaN
# 191 2020-05-07          NaN                  NaN
# 192 2020-05-08          NaN                  NaN
# 193 2020-05-11          NaN                  NaN
# 194 2020-05-12          NaN                  NaN
# 195 2020-05-13          NaN                  NaN
# 196 2020-05-14          NaN                  NaN
# 197 2020-05-15          NaN                  NaN
# 198 2020-05-18          NaN                  NaN
# 199 2020-05-19          NaN                  NaN
# 200 2020-05-20          NaN                  NaN
# 201 2020-05-21          NaN                  NaN
# 202 2020-05-22     1.003115             1.003115
# 203 2020-05-25     1.003115             1.003115
# 204 2020-05-26     1.003115             1.003115
# 205 2020-05-27     1.003115             1.003115
# 206 2020-05-28     1.003115             1.003115
# 207 2020-05-29     1.003115             1.003115

# %%
kc_merged[(kc_merged['Trddt'] >= t1) & (kc_merged['Trddt'] <= t2) & (kc_merged["Stkcd"]==688001)][["Trddt","BwardFactor","CumulateBwardFactor","FwardFactor","CumulateFwardFactor"]]
# Out:
#          Trddt  BwardFactor  CumulateBwardFactor  FwardFactor  \
# 190 2020-05-06          NaN                  NaN          NaN
# 191 2020-05-07          NaN                  NaN          NaN
# 192 2020-05-08          NaN                  NaN          NaN
# 193 2020-05-11          NaN                  NaN          NaN
# 194 2020-05-12          NaN                  NaN          NaN
# 195 2020-05-13          NaN                  NaN          NaN
# 196 2020-05-14          NaN                  NaN          NaN
# 197 2020-05-15          NaN                  NaN          NaN
# 198 2020-05-18          NaN                  NaN          NaN
# 199 2020-05-19          NaN                  NaN          NaN
# 200 2020-05-20          NaN                  NaN          NaN
# 201 2020-05-21          NaN                  NaN          NaN
# 202 2020-05-22     1.003115             1.003115     0.996895
# 203 2020-05-25     1.003115             1.003115     0.996895
# ...

# %%
kc_merged.drop["FwardFactor","CumulateFwardFactor"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 kc_merged.drop["FwardFactor","CumulateFwardFactor"]
#
# TypeError: 'method' object is not subscriptable

# %%
kc_merged = kc_merged.drop(["FwardFactor","CumulateFwardFactor"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 kc_merged = kc_merged.drop(["FwardFactor","CumulateFwardFactor"])
#
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
kc_merged = kc_merged.drop(columns=["FwardFactor","CumulateFwardFactor"])

# %%
kc_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604118 entries, 0 to 604117
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Stkcd                604118 non-null  int64
#  1   Trddt                604118 non-null  datetime64[ns]
#  2   Opnprc               604118 non-null  float64
#  3   Hiprc                604118 non-null  float64
#  4   Loprc                604118 non-null  float64
#  5   Clsprc               604118 non-null  float64
#  6   Dnshrtrd             604118 non-null  int64
#  7   Dnvaltrd             604118 non-null  int64
#  8   Dsmvosd              604118 non-null  float64
#  9   Dsmvtll              604118 non-null  float64
#  10  Dretwd               604118 non-null  float64
#  11  Dretnd               604118 non-null  float64
#  12  Adjprcwd             604118 non-null  float64
#  13  Adjprcnd             604118 non-null  float64
# ...

# %%
fq1 = kc_merged.groupby('Stkcd')['Trddt'].min().reset_index()

# %%
fq1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Stkcd   594 non-null    int64
#  1   Trddt   594 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 9.4 KB

# %%
fq1.head(10)
# Out:
#     Stkcd      Trddt
# 0  688001 2019-07-22
# 1  688002 2019-07-22
# 2  688003 2019-07-22
# 3  688004 2020-06-12
# 4  688005 2019-07-22
# 5  688006 2019-07-22
# 6  688007 2019-07-22
# 7  688008 2019-07-22
# 8  688009 2019-07-22
# 9  688010 2019-07-22

# %%
fq1["FwardFactor"]= fq1["FwardFactor"].fillna(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FwardFactor'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ...

# %%
fq1["FwardFactor"]= 1

# %%
fq1.head(10)
# Out:
#     Stkcd      Trddt  FwardFactor
# 0  688001 2019-07-22            1
# 1  688002 2019-07-22            1
# 2  688003 2019-07-22            1
# 3  688004 2020-06-12            1
# 4  688005 2019-07-22            1
# 5  688006 2019-07-22            1
# 6  688007 2019-07-22            1
# 7  688008 2019-07-22            1
# 8  688009 2019-07-22            1
# 9  688010 2019-07-22            1

# %%
fq1["CumulateFwardFactor"]= 1

# %%
fq1.head(10)
# Out:
#     Stkcd      Trddt  FwardFactor  CumulateFwardFactor
# 0  688001 2019-07-22            1                    1
# 1  688002 2019-07-22            1                    1
# 2  688003 2019-07-22            1                    1
# 3  688004 2020-06-12            1                    1
# 4  688005 2019-07-22            1                    1
# 5  688006 2019-07-22            1                    1
# 6  688007 2019-07-22            1                    1
# 7  688008 2019-07-22            1                    1
# 8  688009 2019-07-22            1                    1
# 9  688010 2019-07-22            1                    1

# %%
kc_merged = kc_merged.groupby("Stkcd")["BwardFactor","CumulateBwardFactor"].fillna(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 kc_merged = kc_merged.groupby("Stkcd")["BwardFactor","CumulateBwardFactor"].fillna(1)
#
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\groupby\generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
#    1951 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.

# %%
kc_merged = kc_merged.groupby("Stkcd")[["BwardFactor","CumulateBwardFactor"]].fillna(1)
# Out:
# <ipython-input-56-8ea5c6599e37>:1: FutureWarning: DataFrameGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use DataFrame.fillna instead
#   kc_merged = kc_merged.groupby("Stkcd")[["BwardFactor","CumulateBwardFactor"]].fillna(1)

# %%
kc_merged.head(10)
# Out:
#    BwardFactor  CumulateBwardFactor
# 0          1.0                  1.0
# 1          1.0                  1.0
# 2          1.0                  1.0
# 3          1.0                  1.0
# 4          1.0                  1.0
# 5          1.0                  1.0
# 6          1.0                  1.0
# 7          1.0                  1.0
# 8          1.0                  1.0
# 9          1.0                  1.0

# %%
kc_merged.tail(10)
# Out:
#         BwardFactor  CumulateBwardFactor
# 604108     1.018846             1.026023
# 604109     1.018846             1.026023
# 604110     1.018846             1.026023
# 604111     1.018846             1.026023
# 604112     1.007046             1.033252
# 604113     1.007046             1.033252
# 604114     1.007046             1.033252
# 604115     1.007046             1.033252
# 604116     1.007046             1.033252
# 604117     1.007046             1.033252

# %%
kc_merged.describe()
# Out:
#          BwardFactor  CumulateBwardFactor
# count  604118.000000        604118.000000
# mean        1.060847             1.142094
# std         0.140466             0.324600
# min         1.000000             1.000000
# 25%         1.000672             1.000790
# 50%         1.005252             1.010638
# 75%         1.013569             1.044295
# max         1.804999             4.840438

# %%
kc_merged = pd.concat(kc, kc_merged)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 kc_merged = pd.concat(kc, kc_merged)
#
# TypeError: concat() takes 1 positional argument but 2 were given

# %%
kc_merged = pd.concat([kc, kc_merged])

# %%
kc_merged.describe()
# Out:
#                Stkcd         Opnprc          Hiprc          Loprc  \
# count  604118.000000  604118.000000  604118.000000  604118.000000
# mean   688338.225042      55.275060      56.804411      53.922815
# std       228.276866      71.140821      73.433663      69.120750
# min    688001.000000       0.640000       0.660000       0.620000
# 25%    688139.000000      20.430000      20.890000      20.000000
# 50%    688307.000000      34.500000      35.350000      33.740000
# 75%    688539.000000      60.940000      62.507500      59.500000
# max    689009.000000    1560.000000    1595.880000    1493.000000
#
#               Clsprc      Dnshrtrd      Dnvaltrd       Dsmvosd       Dsmvtll  \
# count  604118.000000  6.041180e+05  6.041180e+05  6.041180e+05  6.041180e+05
# mean       55.294215  3.826354e+06  1.551123e+08  6.722279e+06  1.217251e+07
# std        71.268711  9.214069e+06  4.203657e+08  1.529865e+07  2.066683e+07
# ...

# %%
kc_merged.head(10)
# Out:
#       Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc    Dnshrtrd  \
# 0  688001.0  2019-07-22   55.40  72.02  39.59   55.50  29010754.0
# 1  688001.0  2019-07-23   46.92  52.65  45.01   48.73  10060618.0
# 2  688001.0  2019-07-24   48.90  52.18  48.90   51.52   9698629.0
# 3  688001.0  2019-07-25   52.78  57.42  52.70   54.71  13056123.0
# 4  688001.0  2019-07-26   54.00  54.00  50.01   50.66   8174241.0
# 5  688001.0  2019-07-29   51.40  55.85  51.40   55.48  10904898.0
# 6  688001.0  2019-07-30   55.40  59.87  53.39   56.79  13962223.0
# 7  688001.0  2019-07-31   57.02  59.69  55.58   58.59  11634422.0
# 8  688001.0  2019-08-01   57.90  70.31  57.00   68.49  19280785.0
# 9  688001.0  2019-08-02   65.68  78.58  65.27   69.92  20888101.0
#
#        Dnvaltrd     Dsmvosd     Dsmvtll  ...  Trdsta  Ahshrtrd_D  Ahvaltrd_D  \
# 0  1.507398e+09  2011851.69  22255500.0  ...     1.0     16200.0    899100.0
# 1  4.959887e+08  1766442.03  19540730.0  ...     1.0     24475.0   1192667.0
# ...

# %%
kc_merged.describe()
# Out:
#                Stkcd         Opnprc          Hiprc          Loprc  \
# count  604118.000000  604118.000000  604118.000000  604118.000000
# mean   688338.225042      55.275060      56.804411      53.922815
# std       228.276866      71.140821      73.433663      69.120750
# min    688001.000000       0.640000       0.660000       0.620000
# 25%    688139.000000      20.430000      20.890000      20.000000
# 50%    688307.000000      34.500000      35.350000      33.740000
# 75%    688539.000000      60.940000      62.507500      59.500000
# max    689009.000000    1560.000000    1595.880000    1493.000000
#
#               Clsprc      Dnshrtrd      Dnvaltrd       Dsmvosd       Dsmvtll  \
# count  604118.000000  6.041180e+05  6.041180e+05  6.041180e+05  6.041180e+05
# mean       55.294215  3.826354e+06  1.551123e+08  6.722279e+06  1.217251e+07
# std        71.268711  9.214069e+06  4.203657e+08  1.529865e+07  2.066683e+07
# ...

# %%
kc_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1208236 entries, 0 to 604117
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Stkcd                604118 non-null  float64
#  1   Trddt                604118 non-null  object
#  2   Opnprc               604118 non-null  float64
#  3   Hiprc                604118 non-null  float64
#  4   Loprc                604118 non-null  float64
#  5   Clsprc               604118 non-null  float64
#  6   Dnshrtrd             604118 non-null  float64
#  7   Dnvaltrd             604118 non-null  float64
#  8   Dsmvosd              604118 non-null  float64
#  9   Dsmvtll              604118 non-null  float64
#  10  Dretwd               604118 non-null  float64
#  11  Dretnd               604118 non-null  float64
#  12  Adjprcwd             604118 non-null  float64
#  13  Adjprcnd             604118 non-null  float64
# ...

# %%
kc_merged.head(10)
# Out:
#       Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc    Dnshrtrd  \
# 0  688001.0  2019-07-22   55.40  72.02  39.59   55.50  29010754.0
# 1  688001.0  2019-07-23   46.92  52.65  45.01   48.73  10060618.0
# 2  688001.0  2019-07-24   48.90  52.18  48.90   51.52   9698629.0
# 3  688001.0  2019-07-25   52.78  57.42  52.70   54.71  13056123.0
# 4  688001.0  2019-07-26   54.00  54.00  50.01   50.66   8174241.0
# 5  688001.0  2019-07-29   51.40  55.85  51.40   55.48  10904898.0
# 6  688001.0  2019-07-30   55.40  59.87  53.39   56.79  13962223.0
# 7  688001.0  2019-07-31   57.02  59.69  55.58   58.59  11634422.0
# 8  688001.0  2019-08-01   57.90  70.31  57.00   68.49  19280785.0
# 9  688001.0  2019-08-02   65.68  78.58  65.27   69.92  20888101.0
#
#        Dnvaltrd     Dsmvosd     Dsmvtll  ...  Trdsta  Ahshrtrd_D  Ahvaltrd_D  \
# 0  1.507398e+09  2011851.69  22255500.0  ...     1.0     16200.0    899100.0
# 1  4.959887e+08  1766442.03  19540730.0  ...     1.0     24475.0   1192667.0
# ...

# %%
kc_merged.tail(10)
# Out:
#         Stkcd Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  Dnvaltrd  \
# 604108    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604109    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604110    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604111    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604112    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604113    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604114    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604115    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604116    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
# 604117    NaN   NaN     NaN    NaN    NaN     NaN       NaN       NaN
#
#         Dsmvosd  Dsmvtll  ...  Trdsta  Ahshrtrd_D  Ahvaltrd_D  PreClosePrice  \
# 604108      NaN      NaN  ...     NaN         NaN         NaN            NaN
# ...

# %%
kc_merged = kc_merged[["BwardFactor","CumulateBwardFactor"]]

# %%
kc_merged = kc_merged.dropna()

# %%
kc_merged.tail(10)
# Out:
#         BwardFactor  CumulateBwardFactor
# 604108     1.018846             1.026023
# 604109     1.018846             1.026023
# 604110     1.018846             1.026023
# 604111     1.018846             1.026023
# 604112     1.007046             1.033252
# 604113     1.007046             1.033252
# 604114     1.007046             1.033252
# 604115     1.007046             1.033252
# 604116     1.007046             1.033252
# 604117     1.007046             1.033252

# %%
kc_merged.head(10)
# Out:
#    BwardFactor  CumulateBwardFactor
# 0          1.0                  1.0
# 1          1.0                  1.0
# 2          1.0                  1.0
# 3          1.0                  1.0
# 4          1.0                  1.0
# 5          1.0                  1.0
# 6          1.0                  1.0
# 7          1.0                  1.0
# 8          1.0                  1.0
# 9          1.0                  1.0

# %%
kc_merged = pd.concat([kc, kc_merged],axis=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 kc_merged = pd.concat([kc, kc_merged],axis=1)
#
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     678         obj_labels = obj.axes[1 - ax]
#     679         if not new_labels.equals(obj_labels):
# --> 680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# ...

# %%
kc
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0       688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1       688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2       688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3       688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4       688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...         ...     ...    ...    ...     ...       ...
# 574660  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 574661  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 574662  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 574663  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 574664  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Markettype    Capchgdt  \
# 0       1507397620   2011851.69  22255500.00  ...          32  2019-07-22
# ...

# %%
kc_merged
# Out:
#         BwardFactor  CumulateBwardFactor
# 0          1.000000             1.000000
# 1          1.000000             1.000000
# 2          1.000000             1.000000
# 3          1.000000             1.000000
# 4          1.000000             1.000000
# ...             ...                  ...
# 604113     1.007046             1.033252
# 604114     1.007046             1.033252
# 604115     1.007046             1.033252
# 604116     1.007046             1.033252
# 604117     1.007046             1.033252
#
# [604118 rows x 2 columns]

# %%
kc_merged = pd.merge(left=kc,right=kc_merged,on=index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 kc_merged = pd.merge(left=kc,right=kc_merged,on=index)
#
# NameError: name 'index' is not defined

# %%
kc_merged = pd.merge(left=kc,right=kc_merged,on=id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-180344350c03> in ?()
# ----> 1 kc_merged = pd.merge(left=kc,right=kc_merged,on=id)
#
# d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
# ...

# %%
kc_merged = pd.concat([kc, kc_merged],axis=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 kc_merged = pd.concat([kc, kc_merged],axis=1)
#
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     678         obj_labels = obj.axes[1 - ax]
#     679         if not new_labels.equals(obj_labels):
# --> 680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# ...

# %%
kc.reset_index()
# Out:
#          index   Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0            0  688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1            1  688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2            2  688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3            3  688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4            4  688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...     ...         ...     ...    ...    ...     ...       ...
# 604113  574660  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  574661  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  574662  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  574663  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  574664  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
# ...

# %%
kc = kc.reset_index()

# %%
kc_merged = kc_merged.reset_index()

# %%
kc_merged = pd.concat([kc, kc_merged],axis=1)

# %%
kc_merged
# Out:
#          index   Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0            0  688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1            1  688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2            2  688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3            3  688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4            4  688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...     ...         ...     ...    ...    ...     ...       ...
# 604113  574660  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  574661  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  574662  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  574663  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  574664  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
# ...

# %%
kc_merged.drop(columns="index")
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0       688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1       688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2       688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3       688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4       688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...         ...     ...    ...    ...     ...       ...
# 604113  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Trdsta  Ahshrtrd_D  \
# 0       1507397620   2011851.69  22255500.00  ...       1       16200
# ...

# %%
kc_merged=kc_merged.drop(columns="index")

# %%
kc_merged
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0       688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1       688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2       688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3       688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4       688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...         ...     ...    ...    ...     ...       ...
# 604113  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Trdsta  Ahshrtrd_D  \
# 0       1507397620   2011851.69  22255500.00  ...       1       16200
# ...

# %%
kc
# Out:
#          index   Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0            0  688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1            1  688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2            2  688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3            3  688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4            4  688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...     ...         ...     ...    ...    ...     ...       ...
# 604113  574660  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  574661  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  574662  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  574663  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  574664  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
# ...

# %%
kc1
# Out:
#         Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0      688001  2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1      688001  2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2      688001  2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3      688001  2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4      688001  2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# ...       ...         ...     ...    ...    ...     ...       ...         ...
# 29448  689009  2020-11-02   50.20  56.78  48.81   56.77  27193402  1428223165
# 29449  689009  2020-11-03   56.50  59.55  53.36   57.39  25121445  1409432109
# 29450  689009  2020-11-04   57.45  57.80  51.90   54.40  20846450  1138491187
# 29451  689009  2020-11-05   55.95  65.28  54.60   61.00  28843507  1764146580
# 29452  689009  2020-11-06   59.80  68.60  59.48   68.60  23162768  1462900126
#
# ...

# %%
kc2
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd   Dnvaltrd  \
# 0       688001  2020-11-09   45.97  47.39  45.30   47.00   2704830  125774342
# 1       688001  2020-11-10   46.08  46.66  44.51   44.75   1924936   87582038
# 2       688001  2020-11-11   44.75  44.88  43.41   43.47   1129307   49676466
# 3       688001  2020-11-12   43.47  44.46  43.47   44.09    677584   29781486
# 4       688001  2020-11-13   44.01  44.79  43.68   44.70    862521   38365209
# ...        ...         ...     ...    ...    ...     ...       ...        ...
# 574660  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446  423667685
# 574661  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938  746256910
# 574662  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964  447706894
# 574663  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400  451546475
# 574664  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766  428039585
#
# ...

# %%
kc = pd.concat([kc1,kc2], ignore_index= True, copy=False)

# %%
kc
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0       688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1       688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2       688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3       688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4       688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...         ...     ...    ...    ...     ...       ...
# 604113  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Markettype    Capchgdt  \
# 0       1507397620   2011851.69  22255500.00  ...          32  2019-07-22
# ...

# %%
kc = kc.sort_values(by=['Stkcd','Trddt'])

# %%
kc
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0       688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1       688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2       688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3       688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4       688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...         ...     ...    ...    ...     ...       ...
# 604113  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Markettype    Capchgdt  \
# 0       1507397620   2011851.69  22255500.00  ...          32  2019-07-22
# ...

# %%
kc.reset_index(drop=True)
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0       688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1       688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2       688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3       688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4       688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...         ...     ...    ...    ...     ...       ...
# 604113  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Markettype    Capchgdt  \
# 0       1507397620   2011851.69  22255500.00  ...          32  2019-07-22
# ...

# %%
kc
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0       688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1       688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2       688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3       688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4       688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...         ...     ...    ...    ...     ...       ...
# 604113  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Markettype    Capchgdt  \
# 0       1507397620   2011851.69  22255500.00  ...          32  2019-07-22
# ...

# %%
kc = kc.reset_index(drop=True)

# %%
fq1
# Out:
#       Stkcd      Trddt  FwardFactor  CumulateFwardFactor
# 0    688001 2019-07-22            1                    1
# 1    688002 2019-07-22            1                    1
# 2    688003 2019-07-22            1                    1
# 3    688004 2020-06-12            1                    1
# 4    688005 2019-07-22            1                    1
# ..      ...        ...          ...                  ...
# 589  688799 2021-07-13            1                    1
# 590  688800 2021-07-22            1                    1
# 591  688819 2021-01-18            1                    1
# 592  688981 2020-07-16            1                    1
# 593  689009 2020-10-29            1                    1
#
# [594 rows x 4 columns]

# %%
fq_df = pd.concat([fq1,kc_adj],ignore_index=True)

# %%
fq_df
# Out:
#          Stkcd      Trddt  FwardFactor  CumulateFwardFactor TradingDate  \
# 0     688001.0 2019-07-22     1.000000             1.000000         NaN
# 1     688002.0 2019-07-22     1.000000             1.000000         NaN
# 2     688003.0 2019-07-22     1.000000             1.000000         NaN
# 3     688004.0 2020-06-12     1.000000             1.000000         NaN
# 4     688005.0 2019-07-22     1.000000             1.000000         NaN
# ...        ...        ...          ...                  ...         ...
# 2676       NaN        NaT     0.975210             0.960002  2024-06-19
# 2677       NaN        NaT     0.984405             0.984405  2025-06-13
# 2678       NaN        NaT     0.993005             0.967818  2024-05-24
# 2679       NaN        NaT     0.981503             0.974635  2025-06-13
# 2680       NaN        NaT     0.993003             0.993003  2025-10-31
#
#         Symbol  BwardFactor  CumulateBwardFactor
# 0          NaN          NaN                  NaN
# ...

# %%
fq_df = fq_df.sort_values(by=["Stkcd","Trddt"])

# %%
fq_df
# Out:
#          Stkcd      Trddt  FwardFactor  CumulateFwardFactor TradingDate  \
# 0     688001.0 2019-07-22     1.000000             1.000000         NaN
# 1     688002.0 2019-07-22     1.000000             1.000000         NaN
# 2     688003.0 2019-07-22     1.000000             1.000000         NaN
# 3     688004.0 2020-06-12     1.000000             1.000000         NaN
# 4     688005.0 2019-07-22     1.000000             1.000000         NaN
# ...        ...        ...          ...                  ...         ...
# 2676       NaN        NaT     0.975210             0.960002  2024-06-19
# 2677       NaN        NaT     0.984405             0.984405  2025-06-13
# 2678       NaN        NaT     0.993005             0.967818  2024-05-24
# 2679       NaN        NaT     0.981503             0.974635  2025-06-13
# 2680       NaN        NaT     0.993003             0.993003  2025-10-31
#
#         Symbol  BwardFactor  CumulateBwardFactor
# 0          NaN          NaN                  NaN
# ...

# %%
fq1[["BwardFactor","CumulateBwardFactor"]] = 1

# %%
fq1
# Out:
#       Stkcd      Trddt  FwardFactor  CumulateFwardFactor  BwardFactor  \
# 0    688001 2019-07-22            1                    1            1
# 1    688002 2019-07-22            1                    1            1
# 2    688003 2019-07-22            1                    1            1
# 3    688004 2020-06-12            1                    1            1
# 4    688005 2019-07-22            1                    1            1
# ..      ...        ...          ...                  ...          ...
# 589  688799 2021-07-13            1                    1            1
# 590  688800 2021-07-22            1                    1            1
# 591  688819 2021-01-18            1                    1            1
# 592  688981 2020-07-16            1                    1            1
# 593  689009 2020-10-29            1                    1            1
#
#      CumulateBwardFactor
# 0                      1
# 1                      1
# 2                      1
# ...

# %%
kc_adj
# Out:
#      TradingDate  Symbol  FwardFactor  BwardFactor  CumulateFwardFactor  \
# 0     2020-05-22  688001     0.996895     1.003115             0.969177
# 1     2021-06-08  688001     0.995431     1.004589             0.972196
# 2     2022-08-05  688001     0.993858     1.006180             0.976658
# 3     2023-06-15  688001     0.990037     1.010064             0.982694
# 4     2024-06-20  688001     0.992583     1.007473             0.992583
# ...          ...     ...          ...          ...                  ...
# 2082  2024-06-19  688819     0.975210     1.025420             0.960002
# 2083  2025-06-13  688819     0.984405     1.015842             0.984405
# 2084  2024-05-24  689009     0.993005     1.007044             0.967818
# 2085  2025-06-13  689009     0.981503     1.018846             0.974635
# 2086  2025-10-31  689009     0.993003     1.007046             0.993003
#
#       CumulateBwardFactor
# 0                1.003115
# 1                1.007718
# ...

# %%
fq2 = pd.DataFrame()

# %%
fq2["Trddt"] = pd.to_datetime(kc_adj["TradingDate"])

# %%
fq2["Stkcd"] = kc_adj["Symbol"]

# %%
fq2[["CumulateFwardFactor","FwardFactor","CumulateBwardFactor","BwardFactor"]] = kc_adj[["CumulateFwardFactor","FwardFactor","CumulateBwardFactor","BwardFactor"]]

# %%
fq2
# Out:
#           Trddt   Stkcd  CumulateFwardFactor  FwardFactor  \
# 0    2020-05-22  688001             0.969177     0.996895
# 1    2021-06-08  688001             0.972196     0.995431
# 2    2022-08-05  688001             0.976658     0.993858
# 3    2023-06-15  688001             0.982694     0.990037
# 4    2024-06-20  688001             0.992583     0.992583
# ...         ...     ...                  ...          ...
# 2082 2024-06-19  688819             0.960002     0.975210
# 2083 2025-06-13  688819             0.984405     0.984405
# 2084 2024-05-24  689009             0.967818     0.993005
# 2085 2025-06-13  689009             0.974635     0.981503
# 2086 2025-10-31  689009             0.993003     0.993003
#
#       CumulateBwardFactor  BwardFactor
# 0                1.003115     1.003115
# 1                1.007718     1.004589
# 2                1.013946     1.006180
# 3                1.024150     1.010064
# 4                1.031804     1.007473
# ...

# %%
fq_df = pd.concat([fq1,fq2],ignore_index=True)

# %%
fq_df
# Out:
#        Stkcd      Trddt  FwardFactor  CumulateFwardFactor  BwardFactor  \
# 0     688001 2019-07-22     1.000000             1.000000     1.000000
# 1     688002 2019-07-22     1.000000             1.000000     1.000000
# 2     688003 2019-07-22     1.000000             1.000000     1.000000
# 3     688004 2020-06-12     1.000000             1.000000     1.000000
# 4     688005 2019-07-22     1.000000             1.000000     1.000000
# ...      ...        ...          ...                  ...          ...
# 2676  688819 2024-06-19     0.975210             0.960002     1.025420
# 2677  688819 2025-06-13     0.984405             0.984405     1.015842
# 2678  689009 2024-05-24     0.993005             0.967818     1.007044
# 2679  689009 2025-06-13     0.981503             0.974635     1.018846
# 2680  689009 2025-10-31     0.993003             0.993003     1.007046
#
#       CumulateBwardFactor
# 0                1.000000
# 1                1.000000
# 2                1.000000
# ...

# %%
fq_df = fq_df.sort_values(by=["Stkcd","Trddt"])

# %%
fq_df
# Out:
#        Stkcd      Trddt  FwardFactor  CumulateFwardFactor  BwardFactor  \
# 0     688001 2019-07-22     1.000000             1.000000     1.000000
# 594   688001 2020-05-22     0.996895             0.969177     1.003115
# 595   688001 2021-06-08     0.995431             0.972196     1.004589
# 596   688001 2022-08-05     0.993858             0.976658     1.006180
# 597   688001 2023-06-15     0.990037             0.982694     1.010064
# ...      ...        ...          ...                  ...          ...
# 592   688981 2020-07-16     1.000000             1.000000     1.000000
# 593   689009 2020-10-29     1.000000             1.000000     1.000000
# 2678  689009 2024-05-24     0.993005             0.967818     1.007044
# 2679  689009 2025-06-13     0.981503             0.974635     1.018846
# 2680  689009 2025-10-31     0.993003             0.993003     1.007046
#
#       CumulateBwardFactor
# 0                1.000000
# 594              1.003115
# 595              1.007718
# ...

# %%
fq_df = fq_df.reset_index(drop=True)

# %%
fq_df
# Out:
#        Stkcd      Trddt  FwardFactor  CumulateFwardFactor  BwardFactor  \
# 0     688001 2019-07-22     1.000000             1.000000     1.000000
# 1     688001 2020-05-22     0.996895             0.969177     1.003115
# 2     688001 2021-06-08     0.995431             0.972196     1.004589
# 3     688001 2022-08-05     0.993858             0.976658     1.006180
# 4     688001 2023-06-15     0.990037             0.982694     1.010064
# ...      ...        ...          ...                  ...          ...
# 2676  688981 2020-07-16     1.000000             1.000000     1.000000
# 2677  689009 2020-10-29     1.000000             1.000000     1.000000
# 2678  689009 2024-05-24     0.993005             0.967818     1.007044
# 2679  689009 2025-06-13     0.981503             0.974635     1.018846
# 2680  689009 2025-10-31     0.993003             0.993003     1.007046
#
#       CumulateBwardFactor
# 0                1.000000
# 1                1.003115
# 2                1.007718
# ...

# %%
kc
# Out:
#          Stkcd       Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd  \
# 0       688001  2019-07-22   55.40  72.02  39.59   55.50  29010754
# 1       688001  2019-07-23   46.92  52.65  45.01   48.73  10060618
# 2       688001  2019-07-24   48.90  52.18  48.90   51.52   9698629
# 3       688001  2019-07-25   52.78  57.42  52.70   54.71  13056123
# 4       688001  2019-07-26   54.00  54.00  50.01   50.66   8174241
# ...        ...         ...     ...    ...    ...     ...       ...
# 604113  689009  2025-11-03   60.53  60.69  59.68   60.14   7053446
# 604114  689009  2025-11-04   60.30  60.37  57.88   58.28  12724938
# 604115  689009  2025-11-05   57.88  58.09  57.40   57.54   7762964
# 604116  689009  2025-11-06   57.35  58.55  57.30   58.39   7755400
# 604117  689009  2025-11-07   58.32  59.07  57.92   58.17   7333766
#
#           Dnvaltrd      Dsmvosd      Dsmvtll  ...  Markettype    Capchgdt  \
# 0       1507397620   2011851.69  22255500.00  ...          32  2019-07-22
# ...

# %%
kc_merged = pd.merge(left=kc,right=fq_df,on=["Stkcd","Trddt"],copy=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 kc_merged = pd.merge(left=kc,right=fq_df,on=["Stkcd","Trddt"],copy=False)
#
# File d:\Programs\Programing\anaconda\envs\quant\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)    167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
# ...

# %%
kc["Trddt"] = pd.to_datetime(kc["Trddt"])

# %%
kc
# Out:
#          Stkcd      Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0       688001 2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1       688001 2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2       688001 2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3       688001 2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4       688001 2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# ...        ...        ...     ...    ...    ...     ...       ...         ...
# 604113  689009 2025-11-03   60.53  60.69  59.68   60.14   7053446   423667685
# 604114  689009 2025-11-04   60.30  60.37  57.88   58.28  12724938   746256910
# 604115  689009 2025-11-05   57.88  58.09  57.40   57.54   7762964   447706894
# 604116  689009 2025-11-06   57.35  58.55  57.30   58.39   7755400   451546475
# 604117  689009 2025-11-07   58.32  59.07  57.92   58.17   7333766   428039585
#
# ...

# %%
fq_df["Trddt"] = pd.to_datetime(fq_df["Trddt"])

# %%
kc_merged = pd.merge(left=kc,right=fq_df,on=["Stkcd","Trddt"],copy=False)

# %%
kc_merged
# Out:
#        Stkcd      Trddt  Opnprc  Hiprc  Loprc  Clsprc   Dnshrtrd     Dnvaltrd  \
# 0     688001 2019-07-22   55.40  72.02  39.59   55.50   29010754   1507397620
# 1     688001 2020-05-22   41.00  41.97  38.60   39.37    2550847    101991873
# 2     688001 2021-06-08   39.29  39.44  37.08   37.37    1845851     70008433
# 3     688001 2022-08-05   34.01  37.00  33.78   35.70    3151859    112065241
# 4     688001 2023-06-15   29.98  30.42  29.63   29.89    2021010     60504010
# ...      ...        ...     ...    ...    ...     ...        ...          ...
# 2675  688981 2020-07-16   95.00  95.00  80.00   82.92  552103902  47967171062
# 2676  689009 2020-10-29   33.00  49.80  33.00   38.50   40954922   1584100687
# 2677  689009 2024-05-24   39.88  40.41  38.91   39.50    4991995    197858901
# 2678  689009 2025-06-13   59.01  60.00  58.00   58.50   10672186    629366791
# 2679  689009 2025-10-31   59.61  61.35  59.60   60.70    8704046    528723619
#
# ...

# %%
kc_merged = pd.merge(left=kc,right=fq_df,how='left',on=["Stkcd","Trddt"],copy=False)

# %%
kc_merged
# Out:
#          Stkcd      Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0       688001 2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1       688001 2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2       688001 2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3       688001 2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4       688001 2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# ...        ...        ...     ...    ...    ...     ...       ...         ...
# 604113  689009 2025-11-03   60.53  60.69  59.68   60.14   7053446   423667685
# 604114  689009 2025-11-04   60.30  60.37  57.88   58.28  12724938   746256910
# 604115  689009 2025-11-05   57.88  58.09  57.40   57.54   7762964   447706894
# 604116  689009 2025-11-06   57.35  58.55  57.30   58.39   7755400   451546475
# 604117  689009 2025-11-07   58.32  59.07  57.92   58.17   7333766   428039585
#
# ...

# %%
kc_merged[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]] = kc_merged.groupby("Stkcd")[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]].fillna('ffill')
# Out:
# <ipython-input-124-3e5cbf78da29>:1: FutureWarning: DataFrameGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use DataFrame.fillna instead
#   kc_merged[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]] = kc_merged.groupby("Stkcd")[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]].fillna('ffill')

# %%
kc_merged
# Out:
#          Stkcd      Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0       688001 2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1       688001 2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2       688001 2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3       688001 2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4       688001 2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# ...        ...        ...     ...    ...    ...     ...       ...         ...
# 604113  689009 2025-11-03   60.53  60.69  59.68   60.14   7053446   423667685
# 604114  689009 2025-11-04   60.30  60.37  57.88   58.28  12724938   746256910
# 604115  689009 2025-11-05   57.88  58.09  57.40   57.54   7762964   447706894
# 604116  689009 2025-11-06   57.35  58.55  57.30   58.39   7755400   451546475
# 604117  689009 2025-11-07   58.32  59.07  57.92   58.17   7333766   428039585
#
# ...

# %%
kc_merged = pd.merge(left=kc,right=fq_df,how='left',on=["Stkcd","Trddt"],copy=False)

# %%
kc_merged[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]] = kc_merged.groupby("Stkcd")[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]].fillna(method='ffill')
# Out:
# <ipython-input-127-833e45815628>:1: FutureWarning: DataFrameGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use DataFrame.fillna instead
#   kc_merged[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]] = kc_merged.groupby("Stkcd")[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]].fillna(method='ffill')
# <ipython-input-127-833e45815628>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   kc_merged[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]] = kc_merged.groupby("Stkcd")[["FwardFactor","CumulateFwardFactor","BwardFactor","CumulateBwardFactor"]].fillna(method='ffill')

# %%
kc_merged
# Out:
#          Stkcd      Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0       688001 2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1       688001 2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2       688001 2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3       688001 2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4       688001 2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# ...        ...        ...     ...    ...    ...     ...       ...         ...
# 604113  689009 2025-11-03   60.53  60.69  59.68   60.14   7053446   423667685
# 604114  689009 2025-11-04   60.30  60.37  57.88   58.28  12724938   746256910
# 604115  689009 2025-11-05   57.88  58.09  57.40   57.54   7762964   447706894
# 604116  689009 2025-11-06   57.35  58.55  57.30   58.39   7755400   451546475
# 604117  689009 2025-11-07   58.32  59.07  57.92   58.17   7333766   428039585
#
# ...

# %%
kc_merged=kc_merged.drop(columns=["FwardFactor","CumulateFwardFactor"])

# %%
kc_merged
# Out:
#          Stkcd      Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0       688001 2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1       688001 2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2       688001 2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3       688001 2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4       688001 2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# ...        ...        ...     ...    ...    ...     ...       ...         ...
# 604113  689009 2025-11-03   60.53  60.69  59.68   60.14   7053446   423667685
# 604114  689009 2025-11-04   60.30  60.37  57.88   58.28  12724938   746256910
# 604115  689009 2025-11-05   57.88  58.09  57.40   57.54   7762964   447706894
# 604116  689009 2025-11-06   57.35  58.55  57.30   58.39   7755400   451546475
# 604117  689009 2025-11-07   58.32  59.07  57.92   58.17   7333766   428039585
#
# ...

# %%
a=fq2.head(0)

# %%
a
# Out:
# Empty DataFrame
# Columns: [Trddt, Stkcd, CumulateFwardFactor, FwardFactor, CumulateBwardFactor, BwardFactor]
# Index: []

# %%
kc.groupby('Stkcd')['Trddt'].min().reset_index()
# Out:
#       Stkcd      Trddt
# 0    688001 2019-07-22
# 1    688002 2019-07-22
# 2    688003 2019-07-22
# 3    688004 2020-06-12
# 4    688005 2019-07-22
# ..      ...        ...
# 589  688799 2021-07-13
# 590  688800 2021-07-22
# 591  688819 2021-01-18
# 592  688981 2020-07-16
# 593  689009 2020-10-29
#
# [594 rows x 2 columns]

# %%
kc_merged
# Out:
#          Stkcd      Trddt  Opnprc  Hiprc  Loprc  Clsprc  Dnshrtrd    Dnvaltrd  \
# 0       688001 2019-07-22   55.40  72.02  39.59   55.50  29010754  1507397620
# 1       688001 2019-07-23   46.92  52.65  45.01   48.73  10060618   495988667
# 2       688001 2019-07-24   48.90  52.18  48.90   51.52   9698629   492116068
# 3       688001 2019-07-25   52.78  57.42  52.70   54.71  13056123   718997834
# 4       688001 2019-07-26   54.00  54.00  50.01   50.66   8174241   423353221
# ...        ...        ...     ...    ...    ...     ...       ...         ...
# 604113  689009 2025-11-03   60.53  60.69  59.68   60.14   7053446   423667685
# 604114  689009 2025-11-04   60.30  60.37  57.88   58.28  12724938   746256910
# 604115  689009 2025-11-05   57.88  58.09  57.40   57.54   7762964   447706894
# 604116  689009 2025-11-06   57.35  58.55  57.30   58.39   7755400   451546475
# 604117  689009 2025-11-07   58.32  59.07  57.92   58.17   7333766   428039585
#
# ...

# %%
print(kc_merged.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604118 entries, 0 to 604117
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Stkcd                604118 non-null  int64
#  1   Trddt                604118 non-null  datetime64[ns]
#  2   Opnprc               604118 non-null  float64
#  3   Hiprc                604118 non-null  float64
#  4   Loprc                604118 non-null  float64
#  5   Clsprc               604118 non-null  float64
#  6   Dnshrtrd             604118 non-null  int64
#  7   Dnvaltrd             604118 non-null  int64
#  8   Dsmvosd              604118 non-null  float64
#  9   Dsmvtll              604118 non-null  float64
#  10  Dretwd               604118 non-null  float64
#  11  Dretnd               604118 non-null  float64
#  12  Adjprcwd             604118 non-null  float64
#  13  Adjprcnd             604118 non-null  float64
# ...

# %%
saved_list = ["CumulateBwardFactor","Stkcd","Trddt","Opnprc","Hiprc","Loprc","Clsprc","Dretwd","Dretnd","Dnshrtrd","Dnvaltrd","Markettype","Dsmvosd","Trdsta","Dsmvtll"]

# %%
df = kc_merged[saved_list].copy()

# %%
df.rename(columns={
    'Stkcd': 'code',
    'Trddt': 'date',
    'Opnprc': 'open',
    'Hiprc': 'high',
    'Loprc': 'low',
    'Clsprc': 'close',
    'Dnshrtrd': 'volume',
    'Dnvaltrd': 'amount',
    'Dsmvosd': 'mkt_cap_float', # 流通市值，注意单位：千
    'Dsmvtll': 'mkt_cap_total', # 总市值，注意单位：千
    'Dretwd': 'pct_chg',       # 收益率
    'CumulateBwardFactor': 'adj_factor', # 最终复权因子
    'Markettype': 'market_type',
    'Trdsta': 'status',
}, inplace=True)
