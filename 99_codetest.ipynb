# %%
import numpy as np
import pandas as pd
import akshare as ak

# stock_sse_summary_df = ak.stock_sse_summary()
# print(stock_sse_summary_df)

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="600519", period="daily", start_date="20230801", end_date='20230811', adjust="")
print(stock_zh_a_hist_df)

stock_zh_a_hist_sl = ak.stock_zh_a_daily(symbol="sh600519", start_date="20230801", end_date='20230811', adjust="")
print(stock_zh_a_hist_sl)
# Out:
#            日期    股票代码       开盘       收盘       最高       最低    成交量  \
# 0  2023-08-01  600519  1878.01  1889.00  1906.95  1877.89  19231
# 1  2023-08-02  600519  1883.40  1880.00  1890.00  1866.80  18509
# 2  2023-08-03  600519  1870.00  1878.47  1890.00  1850.50  21543
# 3  2023-08-04  600519  1887.82  1893.47  1906.52  1882.00  24574
# 4  2023-08-07  600519  1880.95  1887.93  1898.00  1871.03  23892
# 5  2023-08-08  600519  1880.03  1890.00  1893.71  1864.08  17736
# 6  2023-08-09  600519  1890.00  1890.28  1905.00  1882.96  18523
# 7  2023-08-10  600519  1882.00  1875.00  1889.00  1862.30  18436
# 8  2023-08-11  600519  1885.00  1834.00  1885.40  1833.88  26786
#
#             成交额    振幅   涨跌幅    涨跌额   换手率
# 0  3.635857e+09  1.55  0.45   8.42  0.15
# 1  3.478674e+09  1.23 -0.48  -9.00  0.15
# 2  4.031088e+09  2.10 -0.08  -1.53  0.17
# 3  4.655814e+09  1.31  0.80  15.00  0.20
# 4  4.491893e+09  1.42 -0.29  -5.54  0.19
# 5  3.333560e+09  1.57  0.11   2.07  0.14
# ...

# %%
stock_zh_a_hist_sl["volume"].head(5)
# Out:
# 0    1923062.0
# 1    1850872.0
# 2    2154347.0
# 3    2457364.0
# 4    2389245.0
# Name: volume, dtype: float64
