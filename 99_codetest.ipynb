# %%
import numpy as np
import pandas as pd

daily_price_df_kc1 = pd.read_excel("D:/Projects/Quant/CSMAR-Data/科创16-20.xlsx")
daily_price_df_kc2 = pd.read_excel("D:/Projects/Quant/CSMAR-Data/科创20-25.xlsx")
# Out:
# C:\Users\a1226\AppData\Roaming\Python\Python313\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\a1226\AppData\Roaming\Python\Python313\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import pandas as pd
#       4 daily_price_df_kc1 = pd.read_excel("D:/Projects/Quant/CSMAR-Data/科创16-20.xlsx")
# ----> 5 daily_price_df_kc2 = pd.read_excel("D:/Projects/Quant/CSMAR-Data/科创20-25.xlsx")
#
# ...

# %%
# Out:
# 0    1923062.0
# 1    1850872.0
# 2    2154347.0
# 3    2457364.0
# 4    2389245.0
# Name: volume, dtype: float64
